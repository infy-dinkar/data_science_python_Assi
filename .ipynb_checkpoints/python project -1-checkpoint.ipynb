# %%
import pandas as pd

# %%
y=pd.read_csv("Travel.csv")

# %%
y
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
y.head(5)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
y.tail(5)
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
# ...

# %% [markdown]
# # question 1

# %%
y.Age.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %% [markdown]
# # QUESTION-2

# %%
z=y.groupby('TypeofContact')['ProdTaken'].count()

# %%
z
# Out:
# TypeofContact
# Company Invited    1419
# Self Enquiry       3444
# Name: ProdTaken, dtype: int64

# %% [markdown]
# # QUESTION-3

# %%
a=y.groupby('CityTier')['MonthlyIncome'].mean()

# %%
a
# Out:
# CityTier
# 1    23418.100165
# 2    23773.161458
# 3    24023.795549
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# # QUESTION-4

# %%
b=y.groupby('ProdTaken')['DurationOfPitch'].mean()

# %%
b
# Out:
# ProdTaken
# 0    15.169325
# 1    16.873143
# Name: DurationOfPitch, dtype: float64

# %% [markdown]
# # QUESTION-5

# %%
c=y.groupby('Occupation')['ProdTaken'].count()

# %%
c
# Out:
# Occupation
# Free Lancer          2
# Large Business     434
# Salaried          2368
# Small Business    2084
# Name: ProdTaken, dtype: int64

# %%
c.max()
# Out:
# 2368

# %% [markdown]
# # Question-6

# %%
d=y.groupby(['Gender', 'ProductPitched']).count()

# %%
d
# Out:
#                         CustomerID  ProdTaken   Age  TypeofContact  CityTier  \
# Gender  ProductPitched
# Fe Male Basic                    4          4     4              4         4
#         Deluxe                  83         83    83             83        83
#         Standard                63         63    63             63        63
#         Super Deluxe             5          5     5              5         5
# Female  Basic                  676        676   631            672       676
#         Deluxe                 641        641   604            635       641
#         King                    82         82    82             82        82
#         Standard               263        263   263            263       263
#         Super Deluxe           155        155   155            155       155
# Male    Basic                 1162       1162  1063           1156      1162
#         Deluxe                1008       1008   964            999      1008
# ...

# %% [markdown]
# # QUESTION-7

# %%
e=y.groupby('Passport')['NumberOfTrips'].count()

# %%
e
# Out:
# Passport
# 0    3364
# 1    1384
# Name: NumberOfTrips, dtype: int64

# %% [markdown]
# # Question-8

# %%
y
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %% [markdown]
# # QUESTION-9

# %%
f=y.groupby('PitchSatisfactionScore')['NumberOfTrips'].count()

# %%
f
# Out:
# PitchSatisfactionScore
# 1     915
# 2     565
# 3    1445
# 4     890
# 5     933
# Name: NumberOfTrips, dtype: int64

# %% [markdown]
# #  QUESTION-10

# %%
g=y.groupby('NumberOfChildrenVisiting')['NumberOfTrips'].count()

# %%
g
# Out:
# NumberOfChildrenVisiting
# 0.0    1082
# 1.0    2027
# 2.0    1270
# 3.0     303
# Name: NumberOfTrips, dtype: int64

# %% [markdown]
# # QUESTION-11

# %%
#solution of question number -8 is answewr for this question too.

# %% [markdown]
# # QUESTION-12

# %%
h=y.groupby(['MaritalStatus','PreferredPropertyStar'])['NumberOfTrips'].count()

# %%
h
# Out:
# MaritalStatus  PreferredPropertyStar
# Divorced       3.0                       557
#                4.0                       175
#                5.0                       177
# Married        3.0                      1358
#                4.0                       433
#                5.0                       457
# Single         3.0                       553
#                4.0                       175
#                5.0                       155
# Unmarried      3.0                       433
#                4.0                       112
#                5.0                       137
# Name: NumberOfTrips, dtype: int64

# %% [markdown]
# #    QUESTION-13

# %%
#SAME AS QUESTION NUMBER 10

# %% [markdown]
# # QUESTION-14

# %%
i=y.groupby(['OwnCar','ProductPitched'])['NumberOfTrips'].count()

# %%
i
# Out:
# OwnCar  ProductPitched
# 0       Basic              757
#         Deluxe             674
#         King                35
#         Standard           257
#         Super Deluxe        89
# 1       Basic             1080
#         Deluxe            1056
#         King               113
#         Standard           484
#         Super Deluxe       203
# Name: NumberOfTrips, dtype: int64

# %% [markdown]
# # QUESTION-15

# %%
y.groupby('ProductPitched')['MonthlyIncome'].mean()
# Out:
# ProductPitched
# Basic           19939.922507
# Deluxe          22643.157629
# King            35878.947826
# Standard        26637.749326
# Super Deluxe    32241.046784
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# #
